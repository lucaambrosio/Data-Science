# %% [markdown]
# # Esercitazione 5

# %% [markdown]
# ## Istruzioni
# Valgono le stesse istruzioni delle esercitazioni precedenti.
#
# Scrivi il programma Python nella cella sotto il testo dell'esercizio (o creane una nuova). Stampa sempre a video il risultato finale per verificare la correttezza dell'esercizio.  Talvolta richiamiamo alcuni concetti importanti in una cella di codice sotto il testo dell'esercizio, prova a eseguirla ed eventualmente modificarla per assicurarti di aver capito il necessario.
#
# **Nota.** Alcuni esercizi potrebbero richiedere una semplice risposta a delle domande. In questo caso potete scrivere la soluzione in una cella di tipo "Markdown".
#
#
# ## Consegna
# Valgono le regole delle esercitazioni precedenti.
#
# E' obbligatorio **consegnare la soluzione di tutti gli esercizi** (tranne quelli marcati come opzionali) **entro l'inizio della lezione successiva** (in questo caso entro Lunedi' 5 novembre), nell'apposito assignment su iCorsi.  Per consegnare:
# - eseguire l'intero notebook partendo da zero (`Kernel -> Restart & Run All`), e controllare che le soluzioni siano quelle attese;
# - esportare il notebook in formato html (`File -> Download as...`) e consegnare il file risultante.
#
# Nel caso non abbiate potuto completare uno o piu' esercizi, descrivete il problema incontrato e **consegnate comunque il file con il resto delle soluzioni**.

# %% [markdown]
# ## Esercizio 1
#
# ### 1.1
# Si consideri lo scatter plot in figura, che riporta la relazione tra la variabile indipendente ``x`` e la variabile target ``y``.
# ![FigRegr11](attachment:FigRegr1.png)
#
# Una tra le seguenti 4 rette rappresenta il modello di regressione lineare che minimizza il sum-of-squares error (SSE). Quale? Motivate la vostra risposta.
# - $y = 2x+4$
# - $y = 2x-4$
# - $y = -2x-4$
# - $y = -2x+4$

# %% [markdown]
# **Soluzione:**
#
# la soluzione a questa domanda è 2x-4 perché è la retta che più approssima i punti e segue il suo andamento

# %% [markdown]
# ### 1.2
#
# Scrivere una funzione Python ``computePerformance(x,y,w,b)`` che calcola il SSE e il coefficiente di determinazione $R^2$ tra le osservazioni e la retta di regressione $y = wx + b$.
#
# La funzione riceve come argomenti di ingresso:
#     - x: numpy array contente una sequenza della variabile esplicativa
#     - y: numpy array della stessa dimensione di $x$ contente una sequenza della variabile target
#     - w: coefficiente angolare della retta di regressione
#     - b: valore dell'intercetta della retta di regressione
# e restituisce il SSE e l' $R^2$.
#
# Testate la funzione ``computePerformance(x,y,w,b)`` per vari valori di $w$ e $b$ su un set di osservazioni generato in questo modo:
#     - x: array di dimensione 1000 che assume valori casuali (es. valori generati da una distribuzione Gaussiana con media nulla e varianza unitaria)
#     - y=3x-1 + errore, dove errore è un array di variabili casuali Gaussiane a media nulla e varianza $0.1$, e  generato col comando  errore = 0.1*np.random.randn(1000)
#
# Se non avete fatto errori, dovreste osservare che il SSE è "basso" e l' $R^2$ è "prossimo a 1" per valori di $w$ e $b$ vicini a $3$ e $-1$.

# %%
# Solution
import numpy as np
def computePerformance(x,y,w,b):
    SSE=0.0
    SSE=(y-(w*x+b))**2
    R2=0
    #print(SSE)
    somma=np.sum(SSE)
    print(f"SSE = {somma}")
    avg=np.mean(y)
    SST=(y-avg)**2
    sommaSST=np.sum(SST)
    R2=1-(somma/sommaSST)
    
    return somma,R2


x = np.random.randn(1000)
y = 3*x - 1 + 0.1*np.random.randn(1000)

(w,b) = (3,1)
print(f"(w,b)={(w,b)}, (SSE, R2) = {computePerformance(x,y,w,b)}")

(w,b) = (3,-1)
print(f"(w,b)={(w,b)}, (SSE, R2) = {computePerformance(x,y,w,b)}")

(w,b) = (-3,1)
print(f"(w,b)={(w,b)}, (SSE, R2) = {computePerformance(x,y,w,b)}")

(w,b) = (-3,-1)
print(f"(w,b)={(w,b)}, (SSE, R2) = {computePerformance(x,y,w,b)}")
# Out:
# SSE = 4023.019492888169
# (w,b)=(3, 1), (SSE, R2) = (4023.019492888169, 0.5348766294587022)
# SSE = 10.137281923931049
# (w,b)=(3, -1), (SSE, R2) = (10.137281923931049, 0.9988279731816061)
# SSE = 38366.032227956224
# (w,b)=(-3, 1), (SSE, R2) = (38366.032227956224, -3.43570762103168)
# SSE = 34519.49801392511
# (w,b)=(-3, -1), (SSE, R2) = (34519.49801392511, -2.9909886825091756)

# %% [markdown]
# ## Regressione lineare tramite pacchetto scikit-learn
# Il pacchetto Python [scikit-learn](http://scikit-learn.org/stable/index.html) ci permette di calcolare un modello di regressione lineare (sia semplice che multipla) con pochi comandi e in maniera molto efficiente.
#
# Familiarizzate con i comandi principli si scikit-learn eseguendo le celle di questo esercizio oppure guardano gli esempi disponibili [online](http://scikit-learn.org/stable/modules/linear_model.html).
#
# La seguente cella importa il modulo ``linear_model`` dal pacchetto ``scikit-learn`` dove sono definite classi e metodi necessari per costruire un modello di regressione lineare del tipo ``y = x*w+b``. Una volta importato il modulo ``linear_model``, viene costruito un oggetto ``linRegr`` della classe ``LinearRegression``. All'oggetto ``linRegr``viene applicato il metodo ``fit`` per ricavare il modello di regressione.
#
# Nota: il metoto ``fit`` riceve come parametri di ingresso:
#     - x: array di dimensione DUE con i valori delle variabili esplicative. L'array ha m righe e n colonne (dove m è il numero di osservazioni, e n è il numero di variabili esplicative. Nota bene: (i) n=1 nel caso di regressione semplice, (ii) x deve sempre essere un array di dimensione DUE!! Se avete un array di dimensione 1, fate il reshape dell'array tramite il comando np.reshape per trasformarlo in un vettore colonna di dimensione DUE)
#     - y: array con i valori della variabile target di lunghezza m. Nota: y puo' anche essere un array di dimensione 1.
#
# Una volta eseguito il comando fit, potete visualizzare i parametri ``w`` e ``b`` del modello di regressione accedendo agli attributi coef_ e intercept_ dell'oggetto ``linRegr``.

# %%
from sklearn import linear_model

# Definisco l'oggetto della classe LinearRegression
linRegr = linear_model.LinearRegression()


m = len(x) # Numero di osservazioni
x = np.reshape(x,(m,1)) # Trasformo l'array delle variabili esplicative in un array di dimensione 2 (con m righe e 1 colonna)


# Costruisco il modello di regressione lineare
linRegr.fit(x,y)
# Stampo i parametri w e b del modello di regressione
w = linRegr.coef_
b = linRegr.intercept_
print(f"Parametri w: {w}")
print(f"Intercetta b: {b}")
# Out:
# Parametri w: [3.00426886]
# Intercetta b: -1.003250140936242

# %% [markdown]
# Dato un qualunque set di valori della variabile indipendente ``x``, possiamo usare il modello di regressione lineare appena calcolato per stimare il valore della variabile target ``y``. Basta usare il metodo ``predict`` e fornire come ingresso i valori della variabile indipendente.

# %%
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
028156077257957, -1.387017532959104, -0.8720466975604978, -1.2134361149407098, 0.26490405850515236, 1.784499292436493, -0.05068758804820277, 0.11152299554763297, -1.4510657502589148, 0.9626582163463334, 1.5783367758477929, 0.529465430746956, -0.9404386143494696, -0.07334283947442002, -1.0067027543964524, -0.04207394763923102, -0.022274579572751422, 1.5872315157684933, -0.38069007913140795, -0.33814901430658734, 0.8599831337617826, -0.40639101737249844, 0.1488625074383269, 0.7057361190669829, -1.8776321156356497, -1.9195209250859466, -0.5667241580721044, 1.5471872639646265, -0.3430612679178824, -0.2567457039112359, 0.19824918728044214, -0.6609284608475983, -0.23122196744927048, 1.1797679172964193, -1.714584386806601, 0.8630469922395673, -0.39921714475211384, 1.54733166796072, -0.20135430160103995, -1.1406230901398, 1.4783968635370912, -0.31409728374948725, -0.6872385748949636, -0.7342133865449507, 2.211518447659079, 0.951797770101354, 0.061505639622972355, 0.13859477210404514, -0.21155601323144166, -0.9689570754397727, 0.31056898023045804, 1.3514308918859228, 1.649629641469125, 0.4554901300555989, -0.6249551872053538, 1.4312009318602252, 0.26657999664271, 1.1495578234627382, -1.1811043942914776, 0.09516010471706998, 0.7372169920096943, 0.08013471045387269, 2.100163940319939, -0.3512361233517539, -0.0717371799284238, 1.9344545736835153, -0.4796660429023986, 0 ...

# %% [markdown]
# Trick: il metodo ``score`` fornisce il coefficiente di determinazione $R^2$ per il modello di regressione lineare calcolato e per un set di valori della variabile esplicativa ``x`` e della corrispondente variabile target ``y``.

# %%
R2Tool = linRegr.score(x,y)
R2Tool
# Out:
# 0.9988311890291636

# %% [markdown]
# ### 1.3.1 (opzionale)
# Ripete l'esercizio sulla regressione semplice visto a lezione in cui si analizzava la relazione tra lunghezza della mano e altezza di una persona.
#
# Nello specifico:
#     - Calcolate i parametri del modello di regressione lineare ``y=x*w+b`` utilizzando il pacchetto scikit-learn
#     - Disegnare in un unico grafico lo scatter plot delle osservazioni e la retta di regressione
#     - Calcolate il coeffiente di determinazione ``R^2`` utilizzando il metodo ``score``
#     - Usate il metodo ``predict`` per calcolate il valore della funzione ``y = x*w+b`` per ogni valore di x. Calcolate il SSE

# %%
# Punto 1

import pandas as pd
from sklearn import linear_model

# Leggiamo il dataset
df = pd.read_table("http://users.stat.ufl.edu/~winner/data/stature_hand_foot.dat",
                   delim_whitespace=True, names = ["id", "sex", "stature", "hand", "foot"])
x = df["hand"].values # Variabile esplicativa
y = df["stature"].values # Variabile target 
m = len(x)
x = np.reshape(x,(m,1))
linRegr = linear_model.LinearRegression()


# Costruisco il modello di regressione lineare
linRegr.fit(x,y)
# Stampo i parametri w e b del modello di regressione
w = linRegr.coef_
b = linRegr.intercept_
print(f"Parametri w: {w}")
print(f"Intercetta b: {b}")
# Out:
# Parametri w: [6.14601322]
# Intercetta b: 451.4775962062031

# %%
# Punto 2
#Disegnare in un unico grafico lo scatter plot delle osservazioni e la retta di regressione


py.init_notebook_mode(connected=True)
y_retta=w*x[:,0]+b

data=[
    go.Scatter(x=x[:,0],y=y,mode="markers",name="data"),
    go.Scatter(x=x[:,0],y=y_retta,mode="markers",name="retta ")
]
layout = go.Layout()
fig = go.Figure(data, layout)


py.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id
1609.3, 1606.9, 1610.0, 1524.0, 1645.4, 1655.5, 1570.4, 1548.8, 1565.2, 1667.3, 1683.8, 1554.0, 1610.4, 1581.2, 1690.4, 1586.3, 1696.8, 1499.5, 1579.5, 1564.2, 1559.0, 1637.3, 1543.3, 1607.5, 1578.0, 1621.0, 1591.5, 1575.0, 1602.2, 1574.0, 1601.9, 1554.0, 1619.0, 1650.8, 1620.3, 1574.9, 1573.8, 1688.8, 1631.1, 1588.6, 1493.7, 1638.5, 1539.0, 1568.0, 1563.6, 1566.4, 1565.4, 1618.6, 1535.6, 1646.6, 1524.1, 1673.9, 1517.8, 1598.3, 1542.6, 1631.5, 1564.5], "type": "scatter", "uid": "f4213758-df7b-11e8-8643-a402b9828abf"}, {"mode": "markers", "name": "retta ", "x": [208.6, 208.5, 206.8, 204.7, 200.6, 197.6, 204.2, 213.2, 215.5, 211.7, 216.0, 203.3, 214.1, 233.2, 205.6, 207.7, 201.3, 199.8, 219.9, 207.3, 200.4, 204.1, 200.4, 220.3, 216.5, 198.0, 230.9, 202.0, 202.9, 200.5, 196.9, 212.7, 200.2, 214.9, 211.8, 210.0, 220.1, 218.7, 205.5, 206.2, 197.5, 206.2, 206.8, 209.8, 203.7, 212.3, 203.7, 220.4, 207.6, 203.7, 214.3, 219.3, 213.0, 208.8, 210.4, 234.0, 211.4, 231.5, 210.2, 186.9, 218.4, 207.5, 197.0, 187.8, 213.8, 216.1, 214.3, 210.2, 211.3, 211.3, 186.0, 202.7, 213.8, 207.3, 205.4, 204.0, 209.2, 216.6, 208.1, 197.1, 197.8, 201.7, 172.2, 219.4, 183.8, 178.9, 186.9, 185.2, 191.4, 208.2, 207.2, 194.5, 200.5, 189.7, 190.4, 179.1, 188.1, 188.6, 186.1, 188.7, 187.2, 179.0, 201.5, 201.3, 182.1, 189.9, 189.2, 202.1, 192.9, 183.4, 185.9, 184.7, 191.7, 181.2, 212.4, 168.1, 182.8, 190.8, 180.4, 207.4, 192.1, 189.7, 182.1, 184.9, 184.7, 185.2, 187.0, 187.8, 187.4, 191.9, 188.7, 202.7, 189.5, 189.1, 187.3, 203.3, 189.1, 183.4, 172.5, 201.3, 178.2, 182.3, 191.4, 179.8, 189.8, 184.7, 181.4, 200.7, 190.1, 200.9, 188.1, 186.7, 181.1, 183.0, 188.0], "y": [1733.5359540444135, 1732.9213527223435, 1722.473130247152, 1709.56650248368, 1684.3678482788064, 1 ...

# %%
# Punto 3

#Calcolate il coeffiente di determinazione ``R^2`` utilizzando il metodo ``score``


R2=linRegr.score(x,y)
print(f"il coeffiente di determinazione R2 è {R2}")
# Out:
# il coeffiente di determinazione R2 è 0.7623590030663299

# %%
# Punto 4
#Usate il metodo predict per calcolate il valore della funzione y = x*w+b per ogni valore di x. Calcolate il SSE


py.init_notebook_mode(connected=True)
y_pre=linRegr.predict(x)

data=[
   #go.Scatter(x=x[:,0],y=y_retta,mode="markers",name="retta "),
    go.Scatter(x=x[:,0],y=y_pre,mode="markers",name="predict")
]
layout = go.Layout()
fig = go.Figure(data, layout)
py.iplot(fig)

print("i valori della retta calcolati dal metodo predict sono : \n")

print(y_pre)

print("\n\n\n\n\n\n\n\n\n")

print("Calcolo l'SSE :")

SSE=0.0
SSE=(y_pre-(w*x+b))**2
somma=np.sum(SSE)
SSE=0.0
print(f"SSE= {somma}")
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id
#  1602.01127112 1551.61396271 1689.89926018 1688.67005753 1570.6666037
#  1618.60550682 1614.30329756 1693.58686811 1637.04354648 1578.65642088
#  1594.02145393 1586.64623807 1629.66833061 1565.1351918  1756.89080428
#  1484.62241861 1574.96881295 1624.13691872 1560.21838122 1726.16073818
#  1632.1267359  1617.37630417 1570.6666037  1587.87544071 1586.64623807
#  1589.71924468 1600.78206848 1605.69887905 1603.24047377 1630.89753326
#  1611.23029095 1697.27447604 1616.14710153 1613.68869624 1602.62587244
#  1700.96208397 1613.68869624 1578.65642088 1511.66487678 1688.67005753
#  1546.69715214 1571.89580634 1627.82452665 1556.53077329 1617.9909055
#  1586.64623807 1566.36439444 1684.9824496  1619.83470946 1686.21165225
#  1607.54268302 1598.93826451 1564.52059048 1576.19801559 1606.9280817 ]
#
#
#
#
#
#
#
#
#
#
# Calcolo l'SSE :
# SSE= 320977773.54354876

# %% [markdown]
# ## Esercizio 2
# Si consideri il dataset *kc_house_data.csv* disponibile su ``iCorsi``, che contiene informazioni sugli appartamenti venduti da Maggio 2014 a Maggio 2015 nella [King County](https://en.wikipedia.org/wiki/King_County,_Washington). Tra le informazioni disponibili sono presenti prezzo di vendita, caratteristiche dell'abitazione (es., dimensione dell'abitazione, numero di camere da letto, rapporto tra numero di bagni e camere da letto, etc.). Informazioni sul dataset si possono trovare [QUI](https://www.kaggle.com/harlfoxem/housesalesprediction).
#
# L'obbiettivo di questo esercizio è costruire un modello di regressione lineare (sia semplice che multipla) che spieghi la relazione tra le variabili indipendenti (caratteristiche dell'abitazione) e la variabile target (prezzo di vendita).
#
# Eseguite la cella per caricare il dataset (caricheremo solo l'1% dell'intero dataset). Tramite il comando ``train_test_split``, dividiamo in maniera randomica il dataset appena caricato in 2 datasets disgiunti, che chiameremo ``dfTrain`` e ``dfTest`` e che costituiranno, rispettivamente, il set di training (usato per costruire il modello di regressione lineare), e il set di test (usato per valutare le performance del modello di regressione costruito). La dimensione del set di training e del set di test sono il 70% e 30% del dataset.
#
# Visualizzate i dataset caricati, guardate quali sono i nomi degli attributi e capite cosa rappresentano, aiutandovi con la descrizione disponibile online al seguente [link](https://www.kaggle.com/harlfoxem/housesalesprediction).

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split

df = pd.read_csv('kc_house_data.csv')
df = df.sample(frac=0.01, random_state=42) # carico solo l'1% del dataset originale

[dfTrain, dfTest] = train_test_split(df, test_size=0.3, random_state=42) # la dimensione del test set è il 30% del dataset 

# Visualizziamo come è fatto il dataset
print(f"Training dataset: {dfTrain}")
print("\n\n\n\n\n\n\n\n")
print(f"Test: {dfTest}")
# Out:
# Training dataset:                id             date      price  bedrooms  bathrooms  \
# 12838  3296000040  20140923T000000   542000.0         3       2.50
# 12618  6617500085  20150422T000000   500000.0         4       2.50
# 4296   7116500705  20150129T000000   156000.0         2       1.00
# 9414   5700003630  20140630T000000  1925000.0         5       4.25
# 6914   6821600005  20150403T000000   710000.0         4       1.75
# 14298   923000120  20150408T000000   515000.0         3       1.50
# 15468  4202400078  20150128T000000   175000.0         2       1.00
# 21215 -122.082           1950        3825
# 8063  -122.282           1760        7600
# 6909  -122.360           1820        8250
# 21307 -122.072           1260         810
# 13071 -122.290           3370        8700
# 9757  -122.227           1870        9104
# 20693 -122.312           1530        1381
# 1870  -122.307           1820        5120
# 13359 -122.336           1770        5047
# 10366 -122.359           1670        5400
# 5337  -122.095           1540       15000
# 20126 -122.126           3590        6050
# 5937  -122.263           1450        7800
# 6648  -122.317           2220       25265
# 10508 -122.327           1620        4000
# 1227  -122.174           1710        7200
# 554   -122.256           1570        8692
# 5391  -121.896           1660       93393
# 2386  -122.048           1270       17699
#
# [65 rows x 21 columns]

# %% [markdown]
# ### 2.1
# Utilizzando il dataset di training ``dfTrain`` caricato prima, costruite un modello di regressione lineare semplice che spieghi la relazione tra la variabile target *price* (prezzo di vendita in $) e la variabile esplicativa *sqft_living* (dimensione dell'abitazione in ``square feet``).
#
# Nello specifico, si eseguano i seguenti punti:
# - Generate lo scatter plot delle osservazioni. Notate una relazione tra la variabile esplicativa e la variabile target?
# - Calcolate i parametri del modello di regressione lineare ``y=x*w+b``(Hint: usare i comandi del pacchetto scikit-learn)
# - Disegnare in un unico grafico lo scatter plot delle osservazioni del trainig set e la retta di regressione.
# - Calcolate il valore della funzione ``y = x*w+b`` per ogni valore di x del training set e del test set (Hint: usate il comando ``predict``). Si plottino, in 2 figure separate, i residui sul training test e sul test set.
# - Calcolate il coeffiente di determinazione ``R^2``e il SSE sia sul training set che sul test set.
#
# Nota: Si esegua la cella sotto per estrarre dal dataset di training e test la variabile target *price* e la variabile esplicativa *sqft_living*

# %%
# Carichiamo le variabili che ci interessano

yTrain = dfTrain['price'].values
xTrain = dfTrain['sqft_living'].values


yTest = dfTest['price'].values
xTest = dfTest['sqft_living'].values

print(f"Length of training dataset: {len(yTrain)}")
print(f"Length of test dataset: {len(yTest)}")


# Facciamo il reshape delle variabili esplicative per avere array di dimensione 2 con m righe e 1 colonna
mTrain = len(xTrain)
mTest = len(xTest)

xTrain = np.reshape(xTrain,(mTrain,1))
xTest = np.reshape(xTest,(mTest,1))
# Out:
# Length of training dataset: 151
# Length of test dataset: 65

# %%
# Solution (Punto 1)

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
data=[
    go.Scatter(x=xTrain[:,0],y=yTrain,mode="markers")
]
layout = go.Layout()
fig = go.Figure(data, layout)
py.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="acfc6847-5f53-482d-acbb-057ad11de298" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("acfc6847-5f53-482d-acbb-057ad11de298", [{"mode": "markers", "x": [1990, 2900, 920, 4830, 2120, 2200, 1410, 2390, 2420, 2481, 4060, 2820, 840, 1520, 2440, 1090, 3590, 830, 2460, 1640, 2380, 1010, 2220, 2620, 3460, 3770, 1180, 1650, 1750, 1260, 1540, 3270, 1280, 3920, 1040, 1129, 2590, 2830, 1240, 1640, 1930, 1680, 1520, 2690, 520, 2970, 1460, 3180, 2550, 1850, 4120, 2230, 2800, 2330, 1430, 1830, 1290, 1140, 2630, 1600, 2070, 1060, 1347, 2000, 970, 1460, 1010, 2120, 2260, 910, 2790, 1610, 3680, 1790, 4
# %%
# Solution (Punto 3)

#py.init_notebook_mode(connected=True)
#y_retta=w*xTrain[:,0]+b
#xx=xTrain[:,0]

#data=[
#    go.Scatter(x=xTrain[:,0],y=yTrain,mode="markers",name="data"),
#    go.Scatter(x=xTrain[:,0],y=y_retta,mode="markers",name="retta ")
#]
#layout = go.Layout()
#fig = go.Figure(data, layout)


#py.iplot(fig)

#Disegnare in un unico grafico lo scatter plot delle osservazioni del trainig set e la retta di regressione
traceRetta=go.Scatter(x=xTrain[:,0],y=w*xTrain[:,0]+b,name='retta',mode="markers",line = {'color': 'blue'})
traceData=go.Scatter(x=xTrain[:,0], y=yTrain, mode="markers", name="data")
layout = go.Layout(
    xaxis = dict(title="Living in square feet"),
    yaxis = dict(title="Prize")
)
#traceRetta,
fig = go.Figure(data=[traceRetta,traceData], layout=layout)
py.iplot(fig)
# Out:
# <div id="0429ce11-ef04-412c-a5d9-4e4ba66c62a2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0429ce11-ef04-412c-a5d9-4e4ba66c62a2", [{"line": {"color": "blue"}, "mode": "markers", "name": "retta", "x": [1990, 2900, 920, 4830, 2120, 2200, 1410, 2390, 2420, 2481, 4060, 2820, 840, 1520, 2440, 1090, 3590, 830, 2460, 1640, 2380, 1010, 2220, 2620, 3460, 3770, 1180, 1650, 1750, 1260, 1540, 3270, 1280, 3920, 1040, 1129, 2590, 2830, 1240, 1640, 1930, 1680, 1520, 2690, 520, 2970, 1460, 3180, 2550, 1850, 4120, 2230, 2800, 2330, 1430, 1830, 1290, 1140, 2630, 1600, 2070, 1060, 1347, 2000, 970, 1460, 1010, 2120, 2260, 910, 2790, 1610, 3680, 1790, 4285, 1270, 1540, 1580, 1330, 1650, 1710, 5860, 4560, 1700, 1560, 3540, 1520, 2160, 1410, 2290, 2160, 1340, 1800, 1120, 2050, 1500, 3220, 1970, 1140, 1600, 1960, 2790, 2980, 2160, 4360, 850, 1670, 1810, 1390, 1590, 2400, 2290, 1300, 2080, 1630, 1530, 2200, 2560, 1620, 1510, 1180, 5710, 3150, 2590, 2550, 2110, 1750, 2540, 2720, 3600, 2900, 2100, 2260, 1410, 3060, 1830, 2530, 1330, 2090, 2370, 1800, 1110, 1740, 1910, 2280, 1610, 1050, 1140, 2270, 940, 3480], "y": [509436.8717967078, 724818.8505604286, 256185.53412947568, 1181617.992334034, 540205.7259058107, 559140.4053575664, 372160.44577147916, 604110.2690554862, 611210.7738498945, 625648.4669318582, 999371.7026108858, 705884.1711086729, 237250.85467772002, 398195.6300176432, 615944.4437128335, 296421.7279644565, 888130.4608318212, 234884.01974625056, 620678.1135757724, 426597.6491952767, 601743.4341240167, 277487.0485127008, 563874.0752205054, 658547.4724792837, 857361.6067227182, 930733.4895982714, 317723.2423476816, 428964.4841267462, 452632.8334414408, 336657.9217994373, 402929.29988058214, 812391.7430247986, 341391.5916623762, 966236.0135703133, 284587.55330710916, 305652.3841971874, 651446.9676848754, 708251.0060401424, 331924.2519364984, 426597.6491952767, 495235.862207891, 436064.9889211546, 398195.6300176432, 675115.3169995699, 161512.13687069732, 741386.6950807148, 383994.6204288265, 791090.2286415735, 641979.6279589975, 476301.18275613536, 1013572.7121997025, 566240.9101519748, 701150.5012457339, 589909.2594666694, 376894.1156344181, 471567.5128931964, 343758.42659384565, 308255.9026218038, 660914.3074107532, 417130.30946939887, 528371.5512484635, 289321.2231700481, 357249.3857032216, 511803.70672817726, 268019.708786823, 383994.6204288265, 277487.0485127008, 540205.7259058107, 573341.4149463832, 253818.69919800622, 698783.6663142645, 419497.14440086833, 909431.9752150463, 462100.17316731863, 1052625.4885689486, 339024.7567309067, 402929.29988058214, 412396.63960646, 353225.7663197235, 428964.4841267462, 443165.4937155629, 1425401.9902753884, 1117713.4491843588, 440798.6587840935, 407662.96974352107, 876296.2861744739, 398195.6300176432, 549673.0656316886, 372160.44577147916, 580441.9197407915, 549673.0656316886, 355592.601251193, 464467.0080987881, 303522.2327588649, 523637.8813855245, 393461.9601547043, 800557.5683674512, 504703.20193376887, 308255.9026218038, 417130.30946939887, 502336.3670022994, 698783.6663142645, 743753.5300121842, 549673.0656316886, 1070376.7505549695, 239617.6896091895, 433698.1539896851, 466833.84303025756, 367426.77590854024, 414763.47453792946, 606477.1039869556, 580441.9197407915, 346125.2615253151, 530738.3861799329, 424230.81426380726, 400562.4649491127, 559140.4053575664, 644346.4628904669, 421863.9793323378, 395828.79508617375, 317723.2423476816, 1389899.4663033464, 783989.723847165, 651446.9676848754, 641979.6279589975, 537838.8909743413, 452632.8334414408, 639612.793027528, 682215.8217939783, 890497.2957632907, 724818.8505604286, 535472.0560428719, 573341.4149463832, 372160.44577147916, 762688.2094639399, 471567.5128931964, 637245.9580960586, 353225.7663197235, 533105.2211114024, 599376.5991925473, 464467.0080987881 ...

# %%
# Solution (Punto 4)
#Calcolate il valore della funzione y = x*w+b per ogni valore di x del training set e del test set 
#(Hint: usate il comando predict). 
#Si plottino, in 2 figure separate, i residui sul training test e sul test set.
#py.init_notebook_mode(connected=True)
#y_pre=linRegr.predict(xTest)

#data=[
#    go.Scatter(x=xTrain[:,0],y=y_retta,mode="markers",name="retta "),
#   go.Scatter(x=xTest[:,0],y=y_pre,mode="markers",name="predict")
#]
#layout = go.Layout()
#fig = go.Figure(data, layout)


#py.iplot(fig)



mTrain = len(xTrain)
mTest = len(xTest)

xTest = np.reshape(xTest,(len(xTest),1))
yhatTrain=linRegr.predict(xTrain)
yhatTest=linRegr.predict(xTest)
data = [
    go.Scatter(x=xTrain[:,0], y=yTrain-yhatTrain, mode="markers", name="data",line = {'color': 'blue'}),
]
layout = go.Layout(
    xaxis = dict(title="Living in square feet"),
    yaxis = dict(title="Prize")
)
fig = go.Figure(data, layout)
py.iplot(fig)
data1 = [
    go.Scatter(x=xTest[:,0], y=yTest-yhatTest, mode="markers", name="data",line = {'color': 'red'}),
]
layout1 = go.Layout(
    xaxis = dict(title="Living in square feet abc"),
    yaxis = dict(title="Prize abc")
)
fig1 = go.Figure(data1, layout1)
py.iplot(fig1)
# Out:
# <div id="178f2dc4-b5fb-4729-ba3c-fe063f510bf6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Solution (Punto 5)
#Calcolate il coeffiente di determinazione R^2e il SSE sia sul training set che sul test set.


R2test=linRegr.score(xTest,yTest)
R2Train=linRegr.score(xTrain,yTrain)
print(f"coeficiente R2 del data set di Train {R2Train}")
print(f"coeficiente R2 del data set di Test {R2test}")
SSE=0.0
SSE=(yTest-(w*xTest+b))**2
somma=np.sum(SSE)
SSE=0.0
print(f"SSE Test = {somma}")
SSE=(yTrain-(w*xTrain+b))**2
somma=np.sum(SSE)
print(f"SSE Train= {somma}")
# Out:
# coeficiente R2 del data set di Train 0.5286516247278186
# coeficiente R2 del data set di Test 0.3628134134799652
# SSE Test = 831906139992324.0
# SSE Train= 3331524131700658.0

# %% [markdown]
# ### 2.2
# Si ripetano i punti  dell'esercizio precedente, utilizzando come variabile target sempre il prezzo di vendita, ma come variabile esplicativa non piu' la dimensione dell'abitazione, ma la variabile *grade*. La variabile *grade* assume valori tra 1 e 13 e rappresenta la classe di appartenenza dell'abitazione data dalla King County sulla base di una perizia imparziale.

# %%
# Solution (punto 0: Carichiamo le variabili che ci interessano)

yTrain = dfTrain['price'].values
xTrain = dfTrain['grade'].values

yTest = dfTest['price'].values
xTest = dfTest['grade'].values

# Facciamo il reshape delle variabili esplicative per avere array di dimensione 2 con m righe e 1 colonna
mTrain = len(xTrain)
mTest = len(xTest)

xTrain = np.reshape(xTrain,(mTrain,1))
xTest = np.reshape(xTest,(mTest,1))

# %%
# Solution (Punto 1)
#Generate lo scatter plot delle osservazioni. Notate una relazione tra la variabile esplicativa e la variabile target?

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
data=[
    go.Scatter(x=xTrain[:,0],y=yTrain,mode="markers")
]
layout = go.Layout()
fig = go.Figure(data, layout)
py.iplot(fig)

#possiamo notare che all'aumente del grade aumenta anche il prezzo di vendita
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="ea5f87c3-3cb0-4fa2-a963-bced3e9a11fe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ea5f87c3-3cb0-4fa2-a963-bced3e9a11fe", [{"mode": "markers", "x": [8, 8, 6, 11, 8, 7, 7, 9, 8, 8, 10, 10, 5, 6, 8, 7, 9, 6, 7, 8, 8, 7, 7, 9, 9, 11, 6, 6, 8, 6, 7, 8, 6, 9, 7, 7, 9, 10, 6, 7, 7, 7, 7, 9, 5, 8, 6, 8, 9, 8, 10, 8, 8, 9, 7, 8, 6, 6, 9, 7, 8, 6, 7, 7, 7, 7, 6, 8, 7, 6, 8, 7, 8, 7, 10, 8, 7, 8, 6, 7, 7, 10, 12, 7, 6, 9, 7, 8, 6, 7, 9, 7, 7, 7, 7, 7, 9, 7, 7, 8, 7, 9, 8, 7, 10, 5, 8, 7, 7, 7, 7, 8, 8, 8, 7, 7, 8, 8, 6, 7, 7, 11, 9, 9, 8, 7, 7, 8, 9, 8, 8, 9, 7, 7, 8, 7, 8, 7, 7, 8, 8, 6, 8, 7, 7, 7, 7, 6, 8, 6, 10], "y": [542000.0, 500000.0, 156000.0, 1925000.0, 710000.0, 515000.0, 175000.0, 984000.0, 329990.0, 309000.0, 530000.0, 1450000.0, 208417.0, 450000.0, 613000.0, 249000.0, 1302000.0, 282613.0, 240000.0, 602000.0, 725000.0, 290000.0, 467000.0, 683000.0, 730000.0, 1038000.0, 209900.0, 334009.0, 575000.0, 270000.0, 252000.0, 560000.0, 309000.0, 827500.0, 411100.0, 330000.0, 920000.0, 710000.0, 476900.0, 250000.0, 385000.0, 347000.0, 320000.0, 790000.0, 275000.0, 829000.0, 180000.0, 340000.0, 711000.0, 605000.0, 863000.0, 699950.0, 665000.0, 690000.0, 345000.0, 638000.0, 265000.0, 197200.0, 1297000.0, 280000.0, 365000.0, 310000.0, 321000.0, 320000.0, 209500.0, 312000.0, 310000.0, 518500.0, 514000.0, 223000.0, 560000.0, 268000.0, 595000.0, 392000.0, 1890000.0, 531000.0, 500000.0, 495000.0, 375000.0, 400000.0, 362500.0, 1750000.0, 1490000.0, 250000.0, 525000.0, 800000.0, 535000.0, 440000.0, 410000.0, 685000.0, 856000.0, 330000.0, 680000.0, 316000.0, 455000.0, 230000.0, 558000.0, 432000.0, 540000.0, 384500.0, 365000.0, 695000.0, 330000.0, 410000.0, 795127.0, 298000.0, 985000.0, 503500.0, 275000.0, 305000.0, 675000.0, 630000.0, 675000.0, 589950.0, 327000.0, 500000.0, 585000.0, 350000.0, 350000.0, 441500.0, 447500.0, 930000.0, 695000.0, 781000.0, 560000.0, 565000.0, 340000.0, 485000.0, 408500.0, 835000.0, 865000.0, 356000.0, 467500.0, 418000.0, 959750.0, 270000.0, 450000.0, 239000.0, 785000.0, 585000.0, 474900.0, 448000.0, 650500.0, 485000.0, 534000.0, 375000.0, 650000.0, 160000.0, 619850.0, 350000.0, 480000.0], "type": "scatter", "uid": "f54702e8-df7b-11e8-894c-a402b9828abf"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Solution (Punto 2)
#Calcolate i parametri del modello di regressione lineare y=x*w+b(Hint: usare i comandi del pacchetto scikit-learn)
import sklearn
import sklearn.linear_model
linRegr = sklearn.linear_model.LinearRegression()




# Facciamo il reshape delle variabili esplicative per avere array di dimensione 2 con m righe e 1 colonna
xTrain=np.reshape(xTrain,(mTrain,1))

# Costruisco il modello di regressione lineare
linRegr.fit(xTrain, yTrain)
# Stampo i parametri w e b del modello di regressione
w = linRegr.coef_
b = linRegr.intercept_
print(f"Parametri w: {w}")
print(f"Intercetta b: {b}")
# Out:
# Parametri w: [182811.66205833]
# Intercetta b: -851070.4108805384

# %%
# Solution (Punto 3)
#Disegnare in un unico grafico lo scatter plot delle osservazioni del trainig set e la retta di regressione.

py.init_notebook_mode(connected=True)
y_retta=w*xTrain[:,0]+b
xx=xTrain[:,0]

data=[
    go.Scatter(x=xTrain[:,0],y=yTrain,mode="markers",name="data"),
    go.Scatter(x=xTrain[:,0],y=y_retta,mode="markers",name="retta ")
]
layout = go.Layout()
fig = go.Figure(data, layout)


py.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="fd7d72bf-2641-426a-8c63-c895c1219e46" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fd7d72bf-2641-426a-8c63-c895c1219e46", [{"mode": "markers", "name": "data", "x": [8, 8, 6, 11, 8, 7, 7, 9, 8, 8, 10, 10, 5, 6, 8, 7, 9, 6, 7, 8, 8, 7, 7, 9, 9, 11, 6, 6, 8, 6, 7, 8, 6, 9, 7, 7, 9, 10, 6, 7, 7, 7, 7, 9, 5, 8, 6, 8, 9, 8, 10, 8, 8, 9, 7, 8, 6, 6, 9, 
9, 7, 7, 7, 7, 7, 9, 7, 7, 8, 7, 9, 8, 7, 10, 5, 8, 7, 7, 7, 7, 8, 8, 8, 7, 7, 8, 8, 6, 7, 7, 11, 9, 9, 8, 7, 7, 8, 9, 8, 8, 9, 7, 7, 8, 7, 8, 7, 7, 8, 8, 6, 8, 7, 7, 7, 7, 6, 8, 6, 10], "y": [611422.8855860909, 611422.8855860909, 245799.5614694336, 1159857.8717610769, 611422.8855860909, 428611.2235277621, 428611.2235277621, 794234.5476444196, 611422.8855860909, 611422.8855860909, 977046.2097027481, 977046.2097027481, 62987.89941110485, 245799.5614694336, 611422.8855860909, 428611.2235277621, 794234.5476444196, 245799.5614694336, 428611.2235277621, 611422.8855860909, 611422.8855860909, 428611.2235277621, 428611.2235277621, 794234.5476444196, 794234.5476444196, 1159857.8717610769, 245799.5614694336, 245799.5614694336, 611422.8855860909, 245799.5614694336, 428611.2235277621, 611422.8855860909, 245799.5614694336, 794234.5476444196, 428611.2235277621, 428611.2235277621, 794234.5476444196, 977046.2097027481, 245799.5614694336, 428611.2235277621, 428611.2235277621, 428611.2235277621, 428611.2235277621, 794234.5476444196, 62987.89941110485, 611422.8855860909, 245799.5614694336, 611422.8855860909, 794234.5476444196, 611422.8855860909, 977046.2097027481, 611422.8855860909, 611422.8855860909, 794234.5476444196, 428611.2235277621, 611422.885586 ...

# %%
# Solution (Punto 4)
#Calcolate il valore della funzione y = x*w+b per ogni valore di x del training set e del test set
#(Hint: usate il comando predict). Si plottino, in 2 figure separate, i residui sul training test e sul test set.


#py.init_notebook_mode(connected=True)
#y_pre=linRegr.predict(xTest)

#data=[
#    go.Scatter(x=xTrain[:,0],y=y_retta,mode="markers",name="retta "),
#    go.Scatter(x=xTest[:,0],y=y_pre,mode="markers",name="predict")
#]
#layout = go.Layout()
#fig = go.Figure(data, layout)


#py.iplot(fig)



mTrain = len(xTrain)
mTest = len(xTest)

xTest = np.reshape(xTest,(len(xTest),1))
yhatTrain=linRegr.predict(xTrain)
yhatTest=linRegr.predict(xTest)
data = [
    go.Scatter(x=xTrain[:,0], y=yTrain-yhatTrain, mode="markers", name="data",line = {'color': 'blue'}),
]
layout = go.Layout(
    xaxis = dict(title="Living in square feet"),
    yaxis = dict(title="Prize")
)
fig = go.Figure(data, layout)
py.iplot(fig)
data1 = [
    go.Scatter(x=xTest[:,0], y=yTest-yhatTest, mode="markers", name="data",line = {'color': 'red'}),
]
layout1 = go.Layout(
    xaxis = dict(title="Living in square feet abc"),
    yaxis = dict(title="Prize abc")
)
fig1 = go.Figure(data1, layout1)
py.iplot(fig1)
# Out:
# <div id="40d6cc7a-daee-4afc-a2a2-8396a981c052" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
441390915, -438234.5476444196, 38888.77647223789, -10611.223527762108, 348327.11441390915, -158611.2235277621, -161422.88558609085, -189611.2235277621, 356388.7764722379, -26422.88558609085, -136522.88558609085, 202200.4385305664, 39077.11441390915, 56388.77647223789, 105388.77647223789, -53611.22352776211, 221388.7764722379, -85799.5614694336, 8427.114413909148, 104200.4385305664, -497046.2097027481], "type": "scatter", "uid": "f5949e3e-df7b-11e8-a543-a402b9828abf"}], {"xaxis": {"title": "Living in square feet"}, "yaxis": {"title" ...
# <div id="d9b1f563-3063-400f-82b0-36f4abc0f577" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d9b1f563-3063-400f-82b0-36f4abc0f577", [{"line": {"color": "red"}, "mode": "markers", "name": "data", "x": [7, 7, 9, 8, 11, 5, 8, 8, 6, 9, 7, 7, 7, 7, 9, 7, 8, 7, 9, 7, 6, 9, 11, 8, 10, 8, 7, 7, 5, 8, 10, 11, 7, 10, 8, 8, 11, 8, 6, 9, 7, 7, 6, 9, 8, 7, 7, 7, 8, 7, 9, 7, 8, 9, 7, 7, 8, 9, 7, 8, 7, 7, 7, 8, 6], "y": [-108611.22352776211, 11388.776472237892, 480765.4523555804, -147422.88558609085, -89857.87176107685, 172879.10058889515, -138622.88558609085, 238577.11441390915, 74200.4385305664, -221734.5476444196, -115611.22352776211, -3611.2235277621076, -193611.2235277621, 176388.7764722379, 430765.4523555804, -108611.22352776211, -376472.88558609085, -73611.22352776211, -219234.5476444196, -128611.22352776211, -70849.5614694336, -194234.5476444196, 68142.12823892315, -62422.88558609085, 182953.7902972519, -221422.88558609085, -57611.22352776211, 371388.7764722379, 190212.10058889515, -274422.88558609085, -233346.2097027481, -284857.87176107685, 287388.7764722379, -11046.209702748107, -275922.88558609085, -268922.88558609085, -162857.87176107685, 6527.114413909148, 27200.438530566404, 35765.452355580404, -141960.2235277621, 151388.7764722379, 139395.4385305664, 455765.4523555804, 533577.1144139091, 111388.77647223789, -119611.22352776211, -168611.2235277621, -256422.88558609085, -97611.22352776211, 1455765.4523555804, -122611.22352776211, 42577.11441390915, -176234.5476444196, 122388.77647223789, 321388.7764722379, -137422.88558609085, 129755.4523555804, -167611.2235277621, -211422.88558609085, 36388.77647223789, -217611.2235277621, -32611.223527762108, -266422.88558609085, 14200.438530566404], "type": "scatter", "uid": "f59b026e-df7b-11e8-abf8-a402b9828abf"}], {"xaxis": {"title": "Living in square feet abc"}, "yaxis": {"title": "Prize abc"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Solution (Punto 5)




#Calcolate il coeffiente di determinazione R^2e il SSE sia sul training set che sul test set.


R2test=linRegr.score(xTest,yTest)
R2Train=linRegr.score(xTrain,yTrain)
print(f"coeficiente R2 del data set di Train {R2Train}")
print(f"coeficiente R2 del data set di Test {R2test}")
SSE=0.0
SSE=(yTest-(w*xTest+b))**2
somma=np.sum(SSE)
SSE=0.0
print(f"SSE Test = {somma}")
SSE=(yTrain-(w*xTrain+b))**2
somma=np.sum(SSE)
print(f"SSE Train= {somma}")
# Out:
# coeficiente R2 del data set di Train 0.5468329705911341
# coeficiente R2 del data set di Test 0.4342466976086532
# SSE Test = 820953893216189.2
# SSE Train= 3371148328287121.0

# %% [markdown]
# ## 2.3 (Regressione lineare multipla)
#
# Dagli esercizi precedenti abbiamo notato che c'è una relazione tra la variabile *price* e le variabili eslicative *sqft_living* (dimensione dell'appartamento) e *grade* (classe di appartenenza dell'abitazione). Sino ad ora, queste relazioni sono state descritte (in maniera piu' o meno accurata) da 2 modelli indipendenti di regressione lineare semplice.
#
# In questa parte dell'esercizio useremo le due variabili esplicative *sqft_living* e *grade* contemporaneamente per provare a spiegare la variabile target *price*.
#
# Nello specifico, utilizzando sempre il dataset di training *dfTrain* caricato prima, si vuole costruire un unico modello di regressione lineare multipla che spieghi la relazione tra la variabile target e le 2 variabili splicative *sqft_living* e *grade*.
#
#
# Si eseguano i seguenti punti:
# - Generate uno scatter plot 3D delle osservazioni (sull'asse x mettete le osservazioni della variabile *sqft_living*, sull'asse y le osservazioni della variabile *grade*, e sull'asse z le osservazioni della variabile target *price*). Guardate la cella di Hint sotto per capire come generare uno scatter plot tridimensionale.
# - Calcolate i parametri del modello di regressione lineare multipla ``y=x*w+b = sqft_living*w1 + grade*w2 + b``
# - Disegnare in un unico grafico lo scatter plot tridimensionale delle osservazioni del trainig set e il modello di regressione lineare (questo modello sarà un piano). Guardate la cella di Hint sotto per capire come disegnare un piano nello spazio.
# - Calcolate il valore della funzione ``y = x*w+b`` per ogni valore di x del training set e del test set. Si plottino, in 2 figure separate, i residui sul training test e sul test set.
# - Calcolate il coeffiente di determinazione ``R^2``e il SSE sia sul training set che sul test set. Il coefficiente $R^2$ del modello di regressione lineare multipla è piu' alto rispetto all' $R^2$ ottenuto dai singoli modelli di regressione lineare semplice? Quale tra i 3 modelli di regressione lineare calcolati sino ad ora (2 modelli di regressione lineare semplice calcolati al punto 2.1 e 2.2 e il modello di regressione lineare multipla calcolato ora) predice meglio il prezzo di vendita delle case? Hint: Guardare l' $R^2$ sui dati di test.
#
# Nota: Si esegua la cella sotto per caricare le variabile esplicative in un unico array a DUE dimensione, con m righe e 2 colonne.

# %%
xTrain = dfTrain[['sqft_living', 'grade']].values
print(xTrain.shape)

yTrain = dfTrain['price'].values
xTest = dfTest[['sqft_living', 'grade']].values
# Out:
# (151, 2)

# %%
# Hint (3D scatter plot)

x = np.random.randn(1000)
y = np.random.randn(1000)
z = x**2 + y

trace = go.Scatter3d(x = x, y = y, z = z, mode = 'markers', marker = dict(size = 3) ) 
layout = go.Layout(scene = dict(xaxis = dict(title = 'x'), yaxis = dict(title = 'y'), zaxis = dict(title = 'z')))

fig = go.Figure([trace], layout)
py.iplot(fig)
# Out:
# <div id="0d5d10e7-4a96-4f58-8c18-d6cec6261680" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
# %%
# Hint (Disegnare piano nello spazio che passa per punti allineati)

x = np.array([1,2,3])
y = np.array([1,2,3])
z = np.zeros((3,3))

for ind1 in range(len(x)):
    for ind2 in range(len(y)):
        z[ind1,ind2] = 5*x[ind1] + 10*y[ind2] - 0.4   # Equazione del piano
print(z)
trace = go.Surface(x = x, y = y, z = z) 
layout = go.Layout(scene = dict(xaxis = dict(title = 'x'), yaxis = dict(title = 'y'), zaxis = dict(title = 'z')))

fig = go.Figure([trace], layout)
py.iplot(fig)
# Out:
# [[14.6 24.6 34.6]
#  [19.6 29.6 39.6]
#  [24.6 34.6 44.6]]
# <div id="52bac05c-a91d-497f-8960-03d7cd870265" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("52bac05c-a91d-497f-8960-03d7cd870265", [{"x": [1, 2, 3], "y": [1, 2, 3], "z": [[14.6, 24.6, 34.6], [19.6, 29.6, 39.6], [24.6, 34.6, 44.6]], "type": "surface", "uid": "f8bcadc0-df7b-11e8-9ebc-a402b9828abf"}], {"scene": {"xaxis": {"title": "x"}, "yaxis": {"title": "y"}, "zaxis": {"title": "z"}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Solution (punto 1)

#Generate uno scatter plot 3D delle osservazioni 
#(sull'asse x mettete le osservazioni della variabile sqft_living, sull'asse y le osservazioni della variabile grade,
#e sull'asse z le osservazioni della variabile target price). Guardate la cella di Hint sotto per capire come generare 
#uno scatter plot tridimensionale.
              

x = dfTrain['sqft_living'].values
y = dfTrain['grade'].values
z = dfTrain['price'].values

trace = go.Scatter3d(x = x, y = y, z = z, mode = 'markers', marker = dict(size = 3) ) 
layout = go.Layout(scene = dict(xaxis = dict(title = 'x'), yaxis = dict(title = 'y'), zaxis = dict(title = 'z')))

fig = go.Figure([trace], layout)
py.iplot(fig)
# Out:
# <div id="fb2fa6e0-ec0a-4f9b-a2ce-8e8e2c0761e6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fb2fa6e0-ec0a-4f9b-a2ce-8e8e2c0761e6", [{"marker": {"size": 3}, "mode": "markers", "x": [1990, 2900, 920, 4830, 2120, 2200, 1410, 2390, 2420, 2481, 4060, 2820, 840, 1520, 2440, 1090, 3590, 830, 2460, 1640, 2380, 1010, 2220, 2620, 3460, 3770, 1180, 1650, 1750, 1260, 1540, 3270, 1280, 3920, 1040, 1129, 2590, 2830, 1240, 1640, 1930, 1680, 1520, 2690, 520, 2970, 1460, 3180, 2550, 1850, 4120, 2230, 2800, 2330, 1430, 1830, 1290, 1140, 2630, 1600, 2070, 1060, 1347, 2000, 970, 1460, 1010, 2120, 2260, 910, 2790, 1610, 3680, 1790, 4285, 1270, 1540, 1580, 1330, 1650, 1710, 5860, 4560, 1700, 1560, 3540, 1520, 2160, 1410, 2290, 2160, 1340, 1800, 1120, 2050, 1500, 3220, 1970, 1140, 1600, 1960, 2790, 2980, 2160, 4360, 850, 1670, 1810, 1390, 1590, 2400, 2290, 1300, 2080, 1630, 1530, 2
}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Solution (punto 2)
#Calcolate i parametri del modello di regressione lineare multipla y=x*w+b = sqft_living*w1 + grade*w2 + b

#import sklearn
#import sklearn.linear_model

#reg = sklearn.linear_model.LinearRegression()
#x=np.reshape(x,(len(x),1))
#y=np.reshape(y,(len(y),1))
#z=np.reshape(z,(len(z),1))
#reg.fit(x,y,z)
#
#b = reg.intercept_
#w = reg.coef_
#print(f"w1 {w}")
#w1=w[0]
#w2=w[1]

#y_ret=x*w1 + y*w2 + b





import sklearn
import sklearn.linear_model
reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x.reshape((-1, 1)), y.reshape((-1, 1))))
reg.fit(X,z)
b = reg.intercept_
w = reg.coef_
print(b)
print(w)
w1 = w[0]
w2 = w[1]
print(f"w1 e w2 sono {w1} e  {w2}")
y_hat = b + w1 * x + w2 * y
print(y_hat)
# Out:
# -530314.3651233781
# [   116.93347795 108107.19143816]
# w1 e w2 sono 116.93347794762859 e  108107.1914381635
# [ 567240.78749771  673650.25243005  225907.58321742 1223653.43918347
#   582442.1396309   483689.62642855  391312.17884992  722121.37011493
#   617522.18301519  624655.12517    1025507.46972563  880509.95707057
#   108445.71354345  296067.669986    619860.85257414  353893.46590668
#   862441.54365208  215383.57020213  514092.33069493  526314.07021604
#   612844.84389729  344538.78767087  486028.2959875   749016.07004288
#   847240.19151889 1099703.95255898  256310.2874838   311269.02211919
#   539176.75279028  265664.96571961  406513.53098311  716915.63927068
#   268003.63527857  901029.5913748   348046.7920093   358453.87154664
#   745508.06570445  881679.29185005  263326.29616066  418206.87877788
#   452117.58738269  422884.21789578  404174.86142416  757201.41349921
#    71027.00060021  681835.59588639  289051.66130914  706391.62625539
#   740830.72658655  550870.10058504 1032523.47840249  595304.82220514
#   661956.90463529  715105.36143807  393650.84840888  548531.43102609
#   269172.97005804  251632.9483659   750185.40482236  413529.53965997
#   576595.46573352  242278.27013009  383945.36973922  460302.93083902
#   339861.44855297  397158.8527473   236431.59623271  582442.1396309
#   490705.63510541  224738.24843794  660787.56985581  414698.87443945
#   764858.3652292   435746.90047002 1051817.50226385  483048.68337542
#   406513.53098311  519298.06153918  273850.30917595  419376.21355735
#   426392.22223421 1235987.73003136 1300188.59157577  425222.88745473
#   300745.0091039   856594.8697547   404174.86142416  587119.47874881
#   283204.98741176  494213.63944384  695226.67018697  383126.83539359
#   436916.2352495   357401.47024511  466149.6047364   401836.19186521
#   819176.15681146  456794.92650059  359740.13980406  521636.73109814
#   455625.59172112  768894.76129398  683004.93066586  479012.28731064
#  1060587.51310992  109615.04832292  529822.07455447  438085.57002897
#   388973.50929097  412360.2048805   507076.32201807  602320.830882
#   486556.68771385  577764.800513    417037.5439984   405344.19620364
#   591796.81786671  633892.86992786  307761.01778076  403005.52664469
#   364417.47892197 1326554.89977738  810990.81335512  745508.06570445
#   632723.53514838  473165.61341326  431069.56135212  631554.20036891
#   760709.41783764  755503.68699339  673650.25243005  688210.66151011
#   490705.63510541  391312.17884992  692359.60890167  440424.23958793
#   630384.86558943  381957.50061411  470826.94385431  611675.50911781
#   545023.42668766  248124.94402747  538007.4180108   449778.91782374
#   493044.30466436  414698.87443945  349216.12678878  251632.9483659
#   599982.16132305  228246.25277637  957686.052516  ]

# %%
# Solution (punto 3)
#Disegnare in un unico grafico lo scatter plot tridimensionale delle osservazioni del trainig set e
#il modello di regressione lineare (questo modello sarà un piano). Guardate la cella di Hint sotto per capire 
#come disegnare un piano nello spazio.



xTrL = dfTrain['sqft_living'].values
xTrG = dfTrain['grade'].values


x = np.array([np.min(xTrL), np.max(xTrL)])
y = np.array([np.min(xTrG), np.max(xTrG)])
z = np.zeros((3,3))

for ind1 in range(len(x)):
    for ind2 in range(len(y)):
        z[ind1,ind2] = w1*x[ind1] + w2*y[ind2] + b   # Equazione del piano

data = [
    go.Scatter3d(x=xTrL, y=xTrG, z=yTrain, mode="markers", name="data",
                 marker=dict(size=3)),
    go.Surface(x = x , y = y, z= z),
]
layout = go.Layout(
    scene = dict(
        xaxis = dict(title="m^2"),
        yaxis = dict(title="grade"),
        zaxis = dict(title="price")
    )
)
fig = go.Figure(data, layout)
py.iplot(fig)
# Out:
# <div id="df4d52c7-4d83-4576-97f3-f9c92eec4663" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("df4d52c7-4d83-4576-97f3-f9c92eec4663", [{"marker": {"size": 3}, "mode": "markers", "name": "data", "x": [1990, 2900, 920, 4830, 2120, 2200, 1410, 2390, 2420, 2481, 4060, 2820, 840, 1520, 2440, 1090, 3590, 830, 2460, 1640, 2380, 1010, 2220, 2620, 3460, 3770, 1180, 1650, 1750, 1260, 1540, 3270, 1280, 3920, 1040, 1129, 2590, 2830, 1240, 1640, 1930, 1680, 1520, 2690, 520, 2970, 1460, 3180, 2550, 1850, 4120, 2230, 2800, 2330, 1430, 1830, 1290, 1140, 2630, 1600, 2070, 1060, 1347, 2000, 970, 1460, 1010, 2120, 2260, 910, 2790, 1610, 3680, 1790, 4285, 1270, 1540, 1580, 1330, 1650, 1710, 5860, 4560, 1700, 1560, 3540, 1520, 2160, 1410, 2290, 2160, 1340, 1800, 1120, 2050, 1500, 3220, 1970, 1140, 1600, 1960, 2790, 2980, 2160, 4360, 850, 1670, 1810, 1390, 1590, 2400, 2290, 1300, 2080, 1630, 1530, 2200, 2560, 1620, 1510, 1180, 5710, 3150, 2590, 2550, 2110, 1750, 2540, 2720, 3600, 2900, 2100, 2260, 1410, 3060, 1830, 2530, 1330, 2090, 2370, 1800, 1110, 1740, 1910, 2280, 1610, 1050, 1140, 2270, 940, 3480], "y": [8, 8, 6, 11, 8, 7, 7, 9, 8, 8, 10, 10, 5, 6, 8, 7, 9, 6, 7, 8, 8, 7, 7, 9, 9, 11, 6, 6, 8, 6, 7, 8, 6, 9, 7, 7, 9, 10, 6, 7, 7, 7, 7, 9, 5, 8, 6, 8, 9, 8, 10, 8, 8, 9, 7, 8, 6, 6, 9, 
}}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Solution (Punto 4)
#Calcolate il valore della funzione y = x*w+b per ogni valore di x del training set e del test set. 
#Si plottino, in 2 figure separate, i residui sul training test e sul test set.

zhattrain= reg.predict(X)#per il training set
#print(yhat)


xtest = dfTest['sqft_living'].values
ytest = dfTest['grade'].values

Xtest = np.hstack((xtest.reshape((-1, 1)), ytest.reshape((-1, 1))))

zhattest=reg.predict(Xtest)

residuitest=(dfTest['price'].values-zhattest)

#plotto i residui del data frame di test

data1 = [
    go.Scatter3d(x=xtest,y=ytest,z=residuitest, mode="markers", name="data",line = {'color': 'red'}, marker=dict(size=3)),
]
layout1 = go.Layout(
    xaxis = dict(title="Residuo")
)
fig1 = go.Figure(data1, layout1)
py.iplot(fig1)



residuitrain=(dfTrain['price'].values-zhattrain)


#plotto i residui del data frame di train

data1 = [
    go.Scatter3d(x=dfTrain['sqft_living'],y=dfTrain['grade'],z=residuitrain, mode="markers", name="data",line = {'color': 'blue'}, marker=dict(size=3)),
]
layout1 = go.Layout(
    xaxis = dict(title="Residuo")
)
fig1 = go.Figure(data1, layout1)
py.iplot(fig1)
# Out:
# <div id="3a86a2a7-5661-48b5-8a72-c2d173311623" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3a86a2a7-5661-48b5-8a72-c2d173311623", [{"line": {"color": "red"}, "marker": {"size": 3}, "mode": "markers", "name": "data", "x": [2130, 2230, 3720, 3400, 4130, 1330, 1840, 2310, 1190, 2490, 1320, 1360, 1420, 910, 3120, 1110, 1720, 1440, 2990, 3080, 730, 4410, 5730, 1920, 4680, 2330, 1610, 1430, 1360, 1590, 2610, 4720, 1420, 3810, 2240, 2080, 3430, 2410, 2050, 3330, 1830, 3550, 710, 2070, 2490, 1270, 1950, 2320, 1980, 1240, 3420, 1160, 1530, 2340, 2040, 1110, 1960, 3600, 1780, 2320, 1120, 1710, 1300, 1990, 1270], "y": [7, 7, 9, 8, 11, 5, 8, 8, 6, 9, 7, 7, 7, 7, 9, 7, 8, 7, 9, 7, 6, 9, 11, 8, 10, 8, 7, 7, 5, 8, 10, 11, 7, 10, 8, 8, 11, 8, 6, 9, 7, 7, 6, 9, 8, 7, 7, 7, 8, 7, 9, 7, 8, 9, 7, 7, 8, 9, 7, 8, 7, 7, 7, 8, 6], "z": [-155504.2829722152, -47197.63076697814, 397357.10421472834, -268116.991403867, -71800.00462012645, 70123.88226221467, -76900.76580556645, 245340.4995590481, 62520.37773671909, -161314.7179096886, -67788.16583463608, 39534.49504745868, -157481.513629399, 272154.56012389157, 417517.19098330545, -36232.135465634055, -300718.7484518511, -39820.18318835157, -217281.4568835029, -286591.0870224624, -28740.222407371737, -358326.9955691355, -100893.56933633238, -10055.4440413767, 61993.77394684125, -216998.16999990446, -43698.87443944835, 406349.1515911247, 83948.87792378571, -183467.39631865942, -112253.92670156737, -335790.7566092275, 323518.486370601, -30274.100238721818, -260974.15698461793, -235264.80051299743, -62946.57005678653, 1597.151764285285, -85042.41329824144, -2038.8393856966868, -153773.23958792666, -61549.821657847846, 183843.44715158083, 565297.3428283154, 519292.47352847503, 165058.50806274533, -145456.25694164215, -237721.64378226467, -211071.45271823462, -40433.48759882583, 1407437.1475990168, -56078.80936301546, 140548.61235819838, -98274.69621754438, 86019.73004307132, 393767.86453436594, -89732.78315928183, 60379.12156844372, -173577.56569054525, -205828.83522042818, 107598.52975488966, -215392.22223421128, 17550.503724316484, -222240.7874977109, -6834.300499091158], "type": "scatter3d", "uid": "f9329408-df7b-11e8-9b67-a402b9828abf"}], {"xaxis": {"title": "Residuo"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# <div id
748380463, 22739.97788080992, 35823.24720972008, 4335.034280385124, -154513.53098311438, -156915.63927067537, 40996.36472143256, -73529.59137479751, 63053.20799069991, -28453.871546639013, 174491.9342955486, -171679.2918500458, 213573.7038393377, -168206.8787778772, -67117.58738268958, -75884.21789578244, -84174.86142416182, 32798.58650078578, 203972.9993997938, 147164.40411361307, -109051.66130914062, -366391.62625538884, -29830.726586546283, 54129.89941495727, -169523.47840248654, 104645.17779485835, 3043.0953647100832, -25105.361438068096, -48650.84840887529, 89468.56897390983, -4172.97005804372, -54432.9483658995, 546814.5951776435, -133529.53965997207, -211595.46573352115, 67721.72986991087, -62945.36973922211, -140302.93083902355, -130361.44855296612, -85158.85274730413, 73568.40376729227, -63942.13963090256, 23294.364894593018, -1738.248437944916, -100787.56985581364, -146698.87443944835, -169858.36522920313, -43746.90047002153, 838182.4977361546, 47951.316624581814, 93486.46901688562, -24298.061539183138, 101149.69082405115, -19376.213557353476, -63892.22223421128, 514012.2699686396, 189811.40842422983, -175222.887454735, 224254.99089609657, -56594.86975469859, 130825.13857583818, -147119.47874880768, 126795.0125882409, 190786.36055616417, 160773.32981302892, -53126.83539358864, 243083.7647505022, -41401.47024511034, -11149.60473640496, -171836.19186520926, -261176.1568114576, -24794.92650059471, 180259.8601959371, -137136.7310981357, -90625.59172111843, -73894.76129397703, -353004.9306658632, -69012.28731064405, -265460.5131099175, 188384.9516770764, 455177.92544553033, 65414.42997102591, -113973.50929097016, -107360.20488049579, 167923.677981924 ...

# %%
# Solution (punto 5)
#Calcolate il coeffiente di determinazione R^2e il SSE sia sul training set che sul test set.
#Il coefficiente  R2R2  del modello di regressione lineare multipla è piu' alto rispetto all'  R2R2  ottenuto dai singoli
#modelli di regressione lineare semplice? Quale tra i 3 modelli di regressione lineare calcolati sino ad ora
#(2 modelli di regressione lineare semplice calcolati al punto 2.1 e 2.2 e il modello di regressione lineare multipla calcolato 
#ora) predice meglio il prezzo di vendita delle case? Hint: Guardare l'  R2R2  sui dati di test

R2train= reg.score(X,dfTrain['price'].values)
print(f"il valore di R2 è {R2train}");
R2test= reg.score(Xtest,dfTest['price'].values)
print(f"il valore di R2 sui dati di test è {R2test}")

SSE=(dfTrain['price'].values-zhattrain)**2
SSEtrain=np.sum(SSE)
print(f"il valore di SSE del training set è : {SSEtrain}")
SSE=(dfTest['price'].values-zhattest)**2
SSEtrain=np.sum(SSE)
print(f"il valore di SSE del test set è : {SSEtrain}")
# Out:
# il valore di R2 è 0.5845545402053993
# il valore di R2 sui dati di test è 0.4468487910049521
# il valore di SSE del training set è : 5996136502106.154
# il valore di SSE del test set è : 4797445828274.286

# %% [markdown]
# ## 2.4
#
# In questo esercizio studieremo come varia il SSE e il coefficiente di determinazione $R^2$ sia sui dati di training che sui dati di test all'aumentare del numero delle variabili esplicative.
#
#
# Si consideri il solito dataset sulle abitazioni nella King County, la variabile target *price* e il seguente insieme di 8 variabili esplicative (vedere il sito web per capire cosa rappresenta ogni variabile):
#
# ['sqft_living', 'grade', 'lat', 'long', 'yr_built', 'zipcode', 'sqft_lot', 'sqft_basement'].
#
#
# Si costruiscano 8 diversi modelli di regressione lineare con complessità crescente secondo questo criterio:
# - Il primo modello utilizza come variabile esplicativa solo 'sqft_living'
# - Il secondo modello utilizza 2 variabili esplicative ['sqft_living', 'grade']:
# - Il terzo modello utilizza 3 variabili esplicative ['sqft_living', 'grade', 'lat']
# - Il quarto modello utilizza 4 variabili esplicative ['sqft_living', 'grade', 'lat', 'long']
# - ...
# - L'ottavo modello utilizza tutte le 8 variabili esplicative ['sqft_living', 'grade', 'lat', 'long', 'yr_built', 'zipcode', 'sqft_lot', 'sqft_basement'].
#
#
# Si calcolo il SSE e il coefficiente $R^2$ per tutti gli 8 modelli, sia sul set di training che sul set di test.
#
# - E' sempre vero che all'aumentare della complessità del modello l'SSE sul dataset di training diminuisce sempre? Sapete motivare la risposta con la teoria?
# - E' sempre vero che all'aumentare della complessità del modello l' $R^2$ sul dataset di training aumenta sempre?
# - E' sempre vero che all'aumentare della complessità del modello l'SSE sul dataset di test diminuisce sempre?
# - E' sempre vero che all'aumentare della complessità del modello l'$R^2$ sul dataset di test aumenta sempre?

# %%
# Solution (punto 0: Carichiamo tutte le variabili esplicative in un unico array)
xTrain = dfTrain[['sqft_living', 'grade', 'lat', 'long', 'yr_built', 'zipcode', 'sqft_lot', 'sqft_basement']].values
xTest = dfTest[['sqft_living', 'grade', 'lat', 'long', 'yr_built', 'zipcode', 'sqft_lot', 'sqft_basement']].values

# %%
# Solution


#1

print("con variabile espliativa sqft_living!!!")
x1= dfTrain['sqft_living'].values
z= dfTrain['price'].values

x1test=dfTest['sqft_living'].values
ztest=dfTest['price'].values

reg = sklearn.linear_model.LinearRegression()
X=np.reshape(x1,(len(x1),1))
#X = np.hstack((x.reshape((-1, 1)), y.reshape((-1, 1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
x1test=np.reshape(x1test,(len(x1test),1))
reg.fit(x1test,ztest)
z_hat_test=reg.predict(x1test)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(x1test,ztest)
print(f"il valore di R2 del test set è :{R2}")



#2

print("\n\n con variabile espliative sqft_living e grade !!! \n\n\n")
x=dfTrain['sqft_living'].values
y=dfTrain['grade'].values

x1= dfTrain[['sqft_living','grade']].values
z=dfTrain['price'].values

            
xtest=dfTest['sqft_living'].values
ytest=dfTest['grade'].values
x1test=dfTest['sqft_living'].values
ztest=dfTest['price'].values

reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x.reshape((-1, 1)), y.reshape((-1, 1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((xtest.reshape((-1, 1)), ytest.reshape((-1, 1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")





#3

print("\n\n con variabile espliative sqft_living e grade e lat  !!! \n\n\n")
x1=dfTrain['sqft_living'].values
x2=dfTrain['grade'].values
x3=dfTrain['lat'].values
z=dfTrain['price'].values

            
x1test=dfTest['sqft_living'].values
x2test=dfTest['grade'].values
x3test=dfTest['lat'].values

ztest=dfTest['price'].values


reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x1.reshape((-1, 1)), x2.reshape((-1, 1)),x3.reshape((-1,1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((x1test.reshape((-1, 1)), x2test.reshape((-1, 1)),x3test.reshape((-1,1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")


#4

#sqft_living', 'grade', 'lat', 'long', 'yr_built', 'zipcode', 'sqft_lot', 'sqft_basement'

print("\n\n con variabile espliative sqft_living e grade e lat e long  !!! \n\n\n")
x1=dfTrain['sqft_living'].values
x2=dfTrain['grade'].values
x3=dfTrain['lat'].values
x4=dfTrain['long'].values
z=dfTrain['price'].values

            
x1test=dfTest['sqft_living'].values
x2test=dfTest['grade'].values
x3test=dfTest['lat'].values
x4test=dfTest['long'].values

ztest=dfTest['price'].values


reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x1.reshape((-1, 1)), x2.reshape((-1, 1)),x3.reshape((-1,1)),x4.reshape((-1,1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((x1test.reshape((-1, 1)), x2test.reshape((-1, 1)),x3test.reshape((-1,1)),x4test.reshape((-1,1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")




#5




#sqft_living', 'grade', 'lat', 'long', 'yr_built', 'zipcode', 'sqft_lot', 'sqft_basement'

print("\n\n con variabile espliative sqft_living e grade e lat e long e yr_build !!! \n\n\n")
x1=dfTrain['sqft_living'].values
x2=dfTrain['grade'].values
x3=dfTrain['lat'].values
x4=dfTrain['long'].values
x5=dfTrain['yr_built'].values
z=dfTrain['price'].values

            
x1test=dfTest['sqft_living'].values
x2test=dfTest['grade'].values
x3test=dfTest['lat'].values
x4test=dfTest['long'].values
x5test=dfTest['yr_built'].values

ztest=dfTest['price'].values


reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x1.reshape((-1, 1)), x2.reshape((-1, 1)),x3.reshape((-1,1)),x4.reshape((-1,1)),x5.reshape((-1,1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((x1test.reshape((-1, 1)), x2test.reshape((-1, 1)),x3test.reshape((-1,1)),x4test.reshape((-1,1)),x5test.reshape((-1,1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")


#6

#'zipcode', 'sqft_lot', 'sqft_basement'

print("\n\n con variabile espliative sqft_living e grade e lat e long e yr_build e zipcode !!! \n\n\n")
x1=dfTrain['sqft_living'].values
x2=dfTrain['grade'].values
x3=dfTrain['lat'].values
x4=dfTrain['long'].values
x5=dfTrain['yr_built'].values
x6=dfTrain['zipcode'].values
z=dfTrain['price'].values

            
x1test=dfTest['sqft_living'].values
x2test=dfTest['grade'].values
x3test=dfTest['lat'].values
x4test=dfTest['long'].values
x5test=dfTest['yr_built'].values
x6test=dfTest['zipcode'].values

ztest=dfTest['price'].values


reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x1.reshape((-1, 1)), x2.reshape((-1, 1)),x3.reshape((-1,1)),x4.reshape((-1,1)),x5.reshape((-1,1)),x6.reshape((-1,1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((x1test.reshape((-1, 1)), x2test.reshape((-1, 1)),x3test.reshape((-1,1)),x4test.reshape((-1,1)),x5test.reshape((-1,1)),x6test.reshape((-1,1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")


#7
# 'sqft_lot', 'sqft_basement'

print("\n\n con variabile espliative sqft_living e grade e lat e long e yr_build e zipcode e sqft_lot !!! \n\n\n")
x1=dfTrain['sqft_living'].values
x2=dfTrain['grade'].values
x3=dfTrain['lat'].values
x4=dfTrain['long'].values
x5=dfTrain['yr_built'].values
x6=dfTrain['zipcode'].values
x7=dfTrain['sqft_lot'].values
z=dfTrain['price'].values

            
x1test=dfTest['sqft_living'].values
x2test=dfTest['grade'].values
x3test=dfTest['lat'].values
x4test=dfTest['long'].values
x5test=dfTest['yr_built'].values
x6test=dfTest['zipcode'].values
x7test=dfTest['sqft_lot'].values

ztest=dfTest['price'].values


reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x1.reshape((-1, 1)), x2.reshape((-1, 1)),x3.reshape((-1,1)),x4.reshape((-1,1)),x5.reshape((-1,1)),x6.reshape((-1,1)),x7.reshape((-1,1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((x1test.reshape((-1, 1)), x2test.reshape((-1, 1)),x3test.reshape((-1,1)),x4test.reshape((-1,1)),x5test.reshape((-1,1)),x6test.reshape((-1,1)),x7test.reshape((-1,1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")





#8



#'sqft_basement'

print("\n\n con variabile espliative sqft_living e grade e lat e long e yr_build e zipcode e sqft_lot e sqft_basement !!! \n\n\n")
x1=dfTrain['sqft_living'].values
x2=dfTrain['grade'].values
x3=dfTrain['lat'].values
x4=dfTrain['long'].values
x5=dfTrain['yr_built'].values
x6=dfTrain['zipcode'].values
x7=dfTrain['sqft_lot'].values
x8=dfTrain['sqft_basement'].values
z=dfTrain['price'].values

            
x1test=dfTest['sqft_living'].values
x2test=dfTest['grade'].values
x3test=dfTest['lat'].values
x4test=dfTest['long'].values
x5test=dfTest['yr_built'].values
x6test=dfTest['zipcode'].values
x7test=dfTest['sqft_lot'].values
x8test=dfTest['sqft_basement'].values
ztest=dfTest['price'].values


reg = sklearn.linear_model.LinearRegression()
X = np.hstack((x1.reshape((-1, 1)), x2.reshape((-1, 1)),x3.reshape((-1,1)),x4.reshape((-1,1)),x5.reshape((-1,1)),x6.reshape((-1,1)),x7.reshape((-1,1)),x8.reshape((-1,1))))
reg.fit(X,z)
z_hat_train=reg.predict(X)
SSE=(z-z_hat_train)**2
SSE=np.sum(SSE)
print(f"l'SSE del traing set è {SSE}")
R2=reg.score(X,z)
print(f"il valore di R2 del traing set è :{R2}")


#test
Xtest = np.hstack((x1test.reshape((-1, 1)), x2test.reshape((-1, 1)),x3test.reshape((-1,1)),x4test.reshape((-1,1)),x5test.reshape((-1,1)),x6test.reshape((-1,1)),x7test.reshape((-1,1)),x8test.reshape((-1,1))))
reg.fit(Xtest,ztest)
z_hat_test=reg.predict(Xtest)
SSE=(ztest-z_hat_test)**2
SSE=np.sum(SSE)
print(f"l'SSE del test set è {SSE}")
R2=reg.score(Xtest,ztest)
print(f"il valore di R2 del test set è :{R2}")



print("\n\n\n\n\n\nfinito !!!!")
# Out:
# con variabile espliativa sqft_living!!!
# l'SSE del traing set è 6802984920271.568
# il valore di R2 del traing set è :0.5286516247278186
# l'SSE del test set è 5463718925577.064
# il valore di R2 del test set è :0.37002671057168957
#
#
#  con variabile espliative sqft_living e grade !!!
#
#
#
# l'SSE del traing set è 5996136502106.154
# il valore di R2 del traing set è :0.5845545402053993
# l'SSE del test set è 4752327137721.121
# il valore di R2 del test set è :0.45205102967967925
#
#
#  con variabile espliative sqft_living e grade e lat  !!!
#
#
#
# l'SSE del traing set è 4849771578310.343
# il valore di R2 del traing set è :0.6639810346975558
# l'SSE del test set è 4435141648182.258
# il valore di R2 del test set è :0.4886228938120609
#
#
#  con variabile espliative sqft_living e grade e lat e long  !!!
#
#
#
# l'SSE del traing set è 4764197432380.883
# il valore di R2 del traing set è :0.6699100842429934
# l'SSE del test set è 4066290205187.7837
# il valore di R2 del test set è :0.5311519038176526
#
#
#  con variabile espliative sqft_living e grade e lat e long e yr_build !!!
#
#
#
# l'SSE del traing set è 4339491743850.073
# il valore di R2 del traing set è :0.6993360404378016
# l'SSE del test set è 3472851822451.165
# il valore di R2 del test set è :0.5995760550483309
#
#
#  con variabile espliative sqft_living e grade e lat e long e yr_build e zipcode !!!
#
#
#
# l'SSE del traing set è 4204280794203.863
# il valore di R2 del traing set è :0.7087042019406798
# l'SSE del test set è 3468032776429.049
# il valore di R2 del test set è :0.6001316967853623
#
#
#  con variabile espliative sqft_living e grade e lat e long e yr_build e zipcode e sqft_lot !!!
#
#
#
# l'SSE del traing set è 4199911471857.385
# il valore di R2 del traing set è :0.7090069327291777
# l'SSE del test set è 3462953091317.5117
# il valore di R2 del test set è :0.600717390519349
#
#
#  con variabile espliative sqft_living e grade e lat e long e yr_build e zipcode e sqft_lot e sqft_basement !!!
#
#
#
# l'SSE del traing set è 4181826724803.579
# il valore di R2 del traing set è :0.7102599439060244
# l'SSE del test set è 3175043685346.0874
# il valore di R2 del test set è :0.6339136874020648
#
#
#
#
#
#
# finito !!!!

# %% [markdown]
# **Solution**
#
# - E' sempre vero che all'aumentare della complessità del modello l'SSE sul dataset di training diminuisce sempre? Sapete motivare la risposta con la teoria?
#
# - E' sempre vero che all'aumentare della complessità del modello l' $R^2$ sul dataset di training aumenta sempre?
#
# - E' sempre vero che all'aumentare della complessità del modello l'SSE sul dataset di test diminuisce sempre?
#
# - E' sempre vero che all'aumentare della complessità del modello l'$R^2$ sul dataset di test aumenta sempre?

# %% [markdown]
# E' sempre vero che all'aumentare della complessità del modello l'SSE sul dataset di training diminuisce sempre? Sapete motivare la risposta con la teoria?
#
# Risposta :
# Si, perchè più varibili esplicative diamo al nostro modello più preciso saràla nstra approssimazione della variabile target che vogliamo predirre
#
#
# E' sempre vero che all'aumentare della complessità del modello l'  R2R2  sul dataset di training aumenta sempre?
# SI
#
#
# E' sempre vero che all'aumentare della complessità del modello l'SSE sul dataset di test diminuisce sempre?
# SI
#
#
# E' sempre vero che all'aumentare della complessità del modello l' R2R2  sul dataset di test aumenta sempre?
#
# SI
